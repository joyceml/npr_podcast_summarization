# %% [markdown]
# ### References
# https://derwen.ai/docs/ptr/explain_summ/

# %%
import pandas as pd

# %%
df = pd.read_csv('cleaned_transcripts_v2.csv').drop('Unnamed: 0', axis=1)
df = df[df["duration"] > 300]
df.head()
# Out:
#                        title  \
# 0      Letter of Unhappiness
# 1          The Culture Front
# 2  Fighting Words In Ukraine
# 3    May We Have This Dance?
# 4        Moms In Translation
#
#                                                 link  \
# 0  https://www.npr.org/2022/03/30/1089668294/lett...
# 1  https://www.npr.org/2022/03/15/1086679997/the-...
# 2  https://www.npr.org/2022/03/02/1083960666/figh...
# 3  https://www.npr.org/2021/12/22/1066965712/may-...
# 4  https://www.npr.org/2021/12/14/1064250980/moms...
#
#                                          description  duration  podcast_id  \
# 0  When Naira calls her parents back home in Russ...     950.0  1089668294
# 1  When protecting a language is used as justific...    2436.0  1086679997
# 2  Vladimir Putin joined the KGB at age 23. Ukrai...    1883.0  1083960666
# 3  A jazz dance born in Harlem in the 1920s ends ...    2630.0  1066965712
# 4  An Irish journalist discovers she belongs in a...    2519.0  1064250980
#
#                                           transcript  \
# 0  [<div aria-label="Transcript" class="transcrip...
# 1  [<div aria-label="Transcript" class="transcrip...
# 2  [<div aria-label="Transcript" class="transcrip...
# 3  [<div aria-label="Transcript" class="transcrip...
# 4  [<div aria-label="Transcript" class="transcrip...
#
#                                  cleaned_transcripts  \
# 0    You're listening to ROUGH TRANSLATION from N...
# 1    You're listening to ROUGH TRANSLATION from N...
# 2    You're listening to ROUGH TRANSLATION from N...
# 3    This is ROUGH TRANSLATION from NPR. I grew u...
# 4    Hey. It's Gregory from ROUGH TRANSLATION. Ju...
#
#                                  cleaned_description
# 0  When Naira calls her parents back home in Russ...
# 1  When protecting a language is used as justific...
# 2  Vladimir Putin joined the KGB at age 23. Ukrai...
# 3  A jazz dance born in Harlem in the 1920s ends ...
# 4  An Irish journalist discovers she belongs in a...

# %%
#drop nulls in df
df = df[df['cleaned_description'].notna()]
df.reset_index(drop=True, inplace=True)

# %%
# !pip install pytextrank
# !spacy download en_core_web_sm
# Out:
# Collecting pytextrank
#   Downloading pytextrank-3.2.3-py3-none-any.whl (30 kB)
# Collecting graphviz>=0.13
#   Downloading graphviz-0.19.1-py3-none-any.whl (46 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.3/46.3 KB 4.6 MB/s eta 0:00:00
# Collecting icecream>=2.1
#   Downloading icecream-2.1.2-py2.py3-none-any.whl (8.3 kB)
# Requirement already satisfied: pygments>=2.7.4 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from pytextrank) (2.11.2)
# Requirement already satisfied: spacy>=3.0 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from pytextrank) (3.2.3)
# Collecting networkx[default]>=2.6
#   Downloading networkx-2.7.1-py3-none-any.whl (2.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 19.4 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: scipy>=1.7 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from pytextrank) (1.8.0)
# Requirement already satisfied: asttokens>=2.0.1 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from icecream>=2.1->pytextrank) (2.0.5)
# Requirement already satisfied: executing>=0.3.1 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from icecream>=2.1->pytextrank) (0.8.3)
# Collecting colorama>=0.3.9
#   Downloading colorama-0.4.4-py2.py3-none-any.whl (16 kB)
# Requirement already satisfied: numpy>=1.19 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from networkx[default]>=2.6->pytextrank) (1.22.3)
# Requirement already satisfied: pandas>=1.3 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from networkx[default]>=2.6->pytextrank) (1.4.1)
# Requirement already satisfied: matplotlib>=3.4 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from networkx[default]>=2.6->pytextrank) (3.5.1)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from spacy>=3.0->pytextrank) (3.0.6)
# Requirement already satisfied: jinja2 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from spacy>=3.0->pytextrank) (3.0.3)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from spacy>=3.0->pytextrank) (0.7.7)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from spacy>=3.0->pytextrank) (2.0.7)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from spacy>=3.0->pytextrank) (1.8.2)
# Requirement already satisfied: pathy>=0.3.5 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from spacy>=3.0->pytextrank) (0.6.1)
# Requirement already satisfied: srsly<3.0.0,>=2.4.1 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from spacy>=3.0->pytextrank) (2.4.2)
# Requirement already satisfied: typer<0.5.0,>=0.3.0 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from spacy>=3.0->pytextrank) (0.4.0)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.8 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from spacy>=3.0->pytextrank) (3.0.9)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from spacy>=3.0->pytextrank) (2.0.6)
# Requirement already satisfied: wasabi<1.1.0,>=0.8.1 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from spacy>=3.0->pytextrank) (0.9.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from spacy>=3.0->pytextrank) (2.27.1)
# Requirement already satisfied: packaging>=20.0 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from spacy>=3.0->pytextrank) (21.3)
# Requirement already satisfied: thinc<8.1.0,>=8.0.12 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from spacy>=3.0->pytextrank) (8.0.15)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from spacy>=3.0->pytextrank) (1.0.1)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from spacy>=3.0->pytextrank) (1.0.6)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from spacy>=3.0->pytextrank) (4.63.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from spacy>=3.0->pytextrank) (3.3.0)
# Requirement already satisfied: setuptools in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from spacy>=3.0->pytextrank) (49.2.1)
# Requirement already satisfied: six in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from asttokens>=2.0.1->icecream>=2.1->pytextrank) (1.16.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from matplotlib>=3.4->networkx[default]>=2.6->pytextrank) (1.4.0)
# Requirement already satisfied: python-dateutil>=2.7 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from matplotlib>=3.4->networkx[default]>=2.6->pytextrank) (2.8.2)
# Requirement already satisfied: fonttools>=4.22.0 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from matplotlib>=3.4->networkx[default]>=2.6->pytextrank) (4.31.2)
# Requirement already satisfied: pyparsing>=2.2.1 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from matplotlib>=3.4->networkx[default]>=2.6->pytextrank) (3.0.7)
# Requirement already satisfied: pillow>=6.2.0 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from matplotlib>=3.4->networkx[default]>=2.6->pytextrank) (9.0.1)
# Requirement already satisfied: cycler>=0.10 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from matplotlib>=3.4->networkx[default]>=2.6->pytextrank) (0.11.0)
# Requirement already satisfied: pytz>=2020.1 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from pandas>=1.3->networkx[default]>=2.6->pytextrank) (2022.1)
# Requirement already satisfied: smart-open<6.0.0,>=5.0.0 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from pathy>=0.3.5->spacy>=3.0->pytextrank) (5.2.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4->spacy>=3.0->pytextrank) (4.1.1)
# Requirement already satisfied: certifi>=2017.4.17 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy>=3.0->pytextrank) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy>=3.0->pytextrank) (1.26.9)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy>=3.0->pytextrank) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy>=3.0->pytextrank) (3.3)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from typer<0.5.0,>=0.3.0->spacy>=3.0->pytextrank) (8.0.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from jinja2->spacy>=3.0->pytextrank) (2.1.1)
# Installing collected packages: networkx, graphviz, colorama, icecream, pytextrank
# Successfully installed colorama-0.4.4 graphviz-0.19.1 icecream-2.1.2 networkx-2.7.1 pytextrank-3.2.3
# Collecting en-core-web-sm==3.2.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.2.0/en_core_web_sm-3.2.0-py3-none-any.whl (13.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.9/13.9 MB 29.8 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: spacy<3.3.0,>=3.2.0 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from en-core-web-sm==3.2.0) (3.2.3)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.8 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (3.0.9)
# Requirement already satisfied: numpy>=1.15.0 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (1.22.3)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (2.0.6)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (2.27.1)
# Requirement already satisfied: pathy>=0.3.5 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (0.6.1)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (1.8.2)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (0.7.7)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (4.63.1)
# Requirement already satisfied: wasabi<1.1.0,>=0.8.1 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (0.9.0)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (1.0.6)
# Requirement already satisfied: thinc<8.1.0,>=8.0.12 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (8.0.15)
# Requirement already satisfied: jinja2 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (3.0.3)
# Requirement already satisfied: typer<0.5.0,>=0.3.0 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (0.4.0)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (2.0.7)
# Requirement already satisfied: setuptools in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (49.2.1)
# Requirement already satisfied: srsly<3.0.0,>=2.4.1 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (2.4.2)
# Requirement already satisfied: packaging>=20.0 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (21.3)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (1.0.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (3.3.0)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (3.0.6)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from packaging>=20.0->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (3.0.7)
# Requirement already satisfied: smart-open<6.0.0,>=5.0.0 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from pathy>=0.3.5->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (5.2.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (4.1.1)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (1.26.9)
# Requirement already satisfied: certifi>=2017.4.17 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (2021.10.8)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from typer<0.5.0,>=0.3.0->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (8.0.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from jinja2->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (2.1.1)
# Installing collected packages: en-core-web-sm
# Successfully installed en-core-web-sm-3.2.0
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
#write loop to add textrank to df
import spacy
import pytextrank
import scipy
from math import sqrt
from operator import itemgetter
import numpy as np
from rouge_score import rouge_scorer
import time
def run_textrank(df, lim_phrases, target_summ_length, summary_list, rouge_list, ranks_list):
    '''
    Fills 2 lists with textrank summaries and rouge scores.
    Args:
    - df with column ‘cleaned_transcripts’ as text and ‘cleaned_description’ as summary label
    - limit_phrases: number of top phrases to include in unit vector
    - target_summ_length: number of sentences to include in extractive summary
    - summary_list: an empty list to add summaries to
    - rouge_list: an empty list to add rouge scores to
    - ranks_list
    '''
    starttime = time.time()
    for i in range(len(df)):
        # example text
        text = df['cleaned_transcripts'][i]
        # load a spaCy model, depending on language, scale, etc.
        nlp = spacy.load("en_core_web_sm")
        # add PyTextRank to the spaCy pipeline
        nlp.add_pipe("textrank")
        doc = nlp(text)
        #Define sentence bounds
        sent_bounds = [ [s.start, s.end, set([])] for s in doc.sents ]
        #Create unit vector with phrase
        limit_phrases = lim_phrases
        phrase_id = 0
        unit_vector = []
        for p in doc._.phrases:
            unit_vector.append(p.rank)
            for chunk in p.chunks:
                for sent_start, sent_end, sent_vector in sent_bounds:
                    if chunk.start >= sent_start and chunk.end <= sent_end:
                        sent_vector.add(phrase_id)
                        break
            phrase_id += 1
            if phrase_id == limit_phrases:
                break
        #rank sentences based on euclidean distance from unit vector
        sent_rank = {}
        sent_id = 0
        for sent_start, sent_end, sent_vector in sent_bounds:
            sum_sq = 0.0
            for phrase_id in range(len(unit_vector)):
                if phrase_id not in sent_vector:
                    sum_sq += unit_vector[phrase_id]**2.0
            sent_rank[sent_id] = sqrt(sum_sq)
            sent_id += 1
        #sort sentences in order of least distance from unit vector
        ranks = sorted(sent_rank.items(), key=itemgetter(1))
        ranks_list += [ranks[:target_summ_length]]
        #get most important sentences in transcript for summary and record indices
        limit_sentences = target_summ_length
        indices = [i[0] for i in ranks[:limit_sentences]]
        #sort indices
        sorted_indices = list(np.sort(indices))
        sorted_indices
        #save sentences in dictionary
        sent_text = {}
        sent_id = 0
        for sent in doc.sents:
            sent_text[sent_id] = sent.text
            sent_id += 1
        num_sent = 0
        for sent_id, rank in sorted(sent_rank.items(), key=itemgetter(1)):
            #ic(sent_id, sent_text[sent_id])
            num_sent += 1
            if num_sent == limit_sentences:
                break
        #format generated summary
        final_summ = [sent_text[j] for j in sorted_indices]
        final_summ = ' '.join(final_summ)
        #add summary to list
        summary_list += [final_summ]
        #define reference for rouge evaluation
        reference = df['cleaned_description'][i]
        #calculate rouge scores
        scorer = rouge_scorer.RougeScorer(['rouge1', 'rouge2','rougeLsum'], use_stemmer=True)
        scores = scorer.score(final_summ, reference)
        rouge_list += [scores]
    endtime = time.time()
    print (endtime - starttime)

# %%
ext_summaries = []
ext_rouge = []
ext_ranks20 = []

run_textrank(df, 4, 20, ext_summaries, ext_rouge, ext_ranks20)
# Out:
# 5097.180573940277

# %%
len(ext_summaries)
len(ext_rouge)
# Out:
# 4180

# %%
in_top15 = []
for i in range(len(ext_ranks15)):
    switch = 0
    for j in range(15):
        if ext_ranks15[i][j][0] == 0 or ext_ranks15[i][j][0] ==1:
            switch = 1
        else:
            pass
    if switch == 1:
        in_top15 += [i]

# %%
len(in_top15)

# %%
df['ext_summaries'] = ext_summaries
df['ext_rouge'] = ext_rouge

# %%
# df.to_csv('extractive_summaries_v2.csv')

# %%
df.head()
# Out:
#                        title  \
# 0      Letter of Unhappiness
# 1          The Culture Front
# 2  Fighting Words In Ukraine
# 3    May We Have This Dance?
# 4        Moms In Translation
#
#                                                 link  \
# 0  https://www.npr.org/2022/03/30/1089668294/lett...
# 1  https://www.npr.org/2022/03/15/1086679997/the-...
# 2  https://www.npr.org/2022/03/02/1083960666/figh...
# 3  https://www.npr.org/2021/12/22/1066965712/may-...
# 4  https://www.npr.org/2021/12/14/1064250980/moms...
#
#                                          description  duration  podcast_id  \
# 0  When Naira calls her parents back home in Russ...     950.0  1089668294
# 1  When protecting a language is used as justific...    2436.0  1086679997
# 2  Vladimir Putin joined the KGB at age 23. Ukrai...    1883.0  1083960666
# 3  A jazz dance born in Harlem in the 1920s ends ...    2630.0  1066965712
# 4  An Irish journalist discovers she belongs in a...    2519.0  1064250980
#
#                                           transcript  \
# 0  [<div aria-label="Transcript" class="transcrip...
# 1  [<div aria-label="Transcript" class="transcrip...
# 2  [<div aria-label="Transcript" class="transcrip...
# 3  [<div aria-label="Transcript" class="transcrip...
# 4  [<div aria-label="Transcript" class="transcrip...
#
#                                  cleaned_transcripts  \
# 0    You're listening to ROUGH TRANSLATION from N...
# 1    You're listening to ROUGH TRANSLATION from N...
# 2    You're listening to ROUGH TRANSLATION from N...
# 3    This is ROUGH TRANSLATION from NPR. I grew u...
# 4    Hey. It's Gregory from ROUGH TRANSLATION. Ju...
#
#                                  cleaned_description  \
# 0  When Naira calls her parents back home in Russ...
# 1  When protecting a language is used as justific...
# 2  Vladimir Putin joined the KGB at age 23. Ukrai...
# 3  A jazz dance born in Harlem in the 1920s ends ...
# 4  An Irish journalist discovers she belongs in a...
#
#                                        ext_summaries  \
# 0    You're listening to ROUGH TRANSLATION from N...
# 1    You're listening to ROUGH TRANSLATION from N...
# 2  So watching the news out of Ukraine this week,...
# 3  It was called Lindy Hop. LaTasha Barnes, who f...
# 4    Hey. It's Gregory from ROUGH TRANSLATION. In...
#
#                                            ext_rouge
# 0  {'rouge1': (0.6585365853658537, 0.095406360424...
# 1  {'rouge1': (0.6944444444444444, 0.062189054726...
# 2  {'rouge1': (0.625, 0.056818181818181816, 0.104...
# 3  {'rouge1': (0.5714285714285714, 0.042895442359...
# 4  {'rouge1': (0.5483870967741935, 0.057432432432...
